# %% [markdown]
# # 종로구, 중구, 용산구 최종 데이터 합본

# %%
import pandas as pd
import numpy as np

# %%
df_jr = pd.read_csv("data/종로구_최종.csv")
df_jr = df_jr.drop(['Unnamed: 0'], axis=1)
df_jr
# Out:
#     자치구            동  스쿨존 가중치  유동인구 가중치  차량등록 가중치     합계
# 0   종로구          창신동    50.00     24.86     20.00  94.86
# 1   종로구          숭인동    35.57     16.81     12.00  64.38
# 2   종로구          혜화동    38.41     22.44      1.97  62.82
# 3   종로구        청운효자동    42.00     11.96      2.56  56.52
# 4   종로구          부암동    23.02     11.24      7.34  41.60
# 5   종로구  종로1.2.3.4가동    10.12     30.00      0.48  40.60
# 6   종로구      종로5.6가동     7.27     21.26      2.03  30.56
# 7   종로구          사직동    12.52     12.62      1.17  26.31
# 8   종로구          이화동     7.44     17.22      0.69  25.35
# 9   종로구          교남동     2.04     19.53      2.93  24.50
# 10  종로구          평창동     8.35      6.25      9.33  23.93
# 11  종로구          무악동     3.64      4.27     14.18  22.09
# 12  종로구          가회동     4.09     12.78      1.50  18.37

# %%
df_j = pd.read_csv("data/중구_최종.csv")
df_j = df_j.drop(['Unnamed: 0'], axis=1)
df_j
# Out:
#   자치구     동  스쿨존 가중치  유동인구 가중치  차량등록 가중치    합계
# 0  중구   신당동     50.0     10.12     20.00  80.0
# 1  중구  을지로동      0.0     30.00      5.95  36.0
# 2  중구    필동      7.0     23.68      2.39  33.0
# 3  중구   장충동      8.0     14.22      2.48  25.0
# 4  중구    명동      3.0     19.51      0.35  23.0
# 5  중구   회현동      6.0     15.05      2.41  23.0
# 6  중구   황학동      7.0      8.94      6.33  22.0
# 7  중구   소공동      4.0     16.82      0.49  21.0
# 8  중구   광희동      0.0     18.44      0.56  19.0
# 9  중구   중림동     10.0      5.99      3.12  19.0

# %%
df_y = pd.read_csv("data/용산구_최종.csv")
df_y = df_y.drop(['Unnamed: 0'], axis=1)
df_y
# Out:
#     자치구      동  스쿨존 가중치  유동인구 가중치  차량등록 가중치     합계
# 0   용산구    한남동    50.00      7.30      5.92  63.21
# 1   용산구    청파동    37.71     14.38      6.91  58.99
# 2   용산구    보광동    18.97     14.57     20.00  53.54
# 3   용산구  용산2가동     6.88     28.95     17.42  53.25
# 4   용산구   이태원동     0.01     30.00      9.17  39.18
# 5   용산구  원효로2동    27.37      8.29      1.96  37.61
# 6   용산구   서빙고동    24.53      5.50      4.26  34.28
# 7   용산구   한강로동    17.65      7.70      6.67  32.02
# 8   용산구    효창동     5.63     11.52     11.75  28.90
# 9   용산구    이촌동     0.03     10.67     14.71  25.41
# 10  용산구  원효로1동    16.48      5.32      3.27  25.07
# 11  용산구    용문동     7.59      6.49      5.73  19.81
